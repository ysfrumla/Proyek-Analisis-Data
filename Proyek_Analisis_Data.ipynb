# %% [markdown]
# # Proyek Analisis Data: E-Commerce Public Dataset
# - **Nama:** Marchel Yusuf Rumlawang Arpipi
# - **Email:** ysfrumla@gmail.com
# - **ID Dicoding:** ysfrum

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Produk apa yang memiliki jumlah pembelian terbanyak?
# - Seberapa puas pelanggan terhadap layanan yang diberikan (review)?
# - Bagaimana data pembelian bulanan?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import datetime as dt
import matplotlib.pyplot as plt
from unidecode import unidecode

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
customers_df = pd.read_csv('/content/drive/MyDrive/machine_learning/E-Commerce Public Dataset/customers_dataset.csv')
customers_df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
geolocation_df = pd.read_csv('/content/drive/MyDrive/machine_learning/E-Commerce Public Dataset/geolocation_dataset.csv')
geolocation_df.head()
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %%
order_items_df = pd.read_csv('/content/drive/MyDrive/machine_learning/E-Commerce Public Dataset/order_items_dataset.csv')
order_items_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# ...

# %%
order_payments_df = pd.read_csv('/content/drive/MyDrive/machine_learning/E-Commerce Public Dataset/order_payments_dataset.csv')
order_payments_df.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
order_reviews_df = pd.read_csv('/content/drive/MyDrive/machine_learning/E-Commerce Public Dataset/order_reviews_dataset.csv')
order_reviews_df.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# ...

# %%
orders_df = pd.read_csv('/content/drive/MyDrive/machine_learning/E-Commerce Public Dataset/orders_dataset.csv')
orders_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
product_category_name_translation_df = pd.read_csv('/content/drive/MyDrive/machine_learning/E-Commerce Public Dataset/product_category_name_translation.csv')
product_category_name_translation_df.head()
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %%
products_df = pd.read_csv('/content/drive/MyDrive/machine_learning/E-Commerce Public Dataset/products_dataset.csv')
products_df.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %%
sellers_df = pd.read_csv('/content/drive/MyDrive/machine_learning/E-Commerce Public Dataset/sellers_dataset.csv')
sellers_df.head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# #####Melihat informasi yang ada pada data.

# %%
customers_df.info()
print()
geolocation_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000163 entries, 0 to 1000162
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   geolocation_zip_code_prefix  1000163 non-null  int64
#  1   geolocation_lat              1000163 non-null  float64
#  2   geolocation_lng              1000163 non-null  float64
# ...

# %%
order_items_df.info()
print()
order_payments_df.info()
print()
order_reviews_df.info()
print()
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              103886 non-null  object
#  1   payment_sequential    103886 non-null  int64
# ...

# %%
product_category_name_translation_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 2 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   product_category_name          71 non-null     object
#  1   product_category_name_english  71 non-null     object
# dtypes: object(2)
# memory usage: 1.2+ KB

# %%
products_df.info()
print()
sellers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3095 entries, 0 to 3094
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ...

# %% [markdown]
# #####Memeriksa apakah ada missing value atau tidak.

# %%
customers_df.isna().sum()
# Out:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %%
geolocation_df.isna().sum()
# Out:
# geolocation_zip_code_prefix    0
# geolocation_lat                0
# geolocation_lng                0
# geolocation_city               0
# geolocation_state              0
# dtype: int64

# %%
order_items_df.isna().sum()
# Out:
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64

# %%
order_payments_df.isna().sum()
# Out:
# order_id                0
# payment_sequential      0
# payment_type            0
# payment_installments    0
# payment_value           0
# dtype: int64

# %%
order_reviews_df.isna().sum()
# Out:
# review_id                      0
# order_id                       0
# review_score                   0
# review_comment_title       87656
# review_comment_message     58247
# review_creation_date           0
# review_answer_timestamp        0
# dtype: int64

# %%
orders_df.isna().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %%
product_category_name_translation_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 2 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   product_category_name          71 non-null     object
#  1   product_category_name_english  71 non-null     object
# dtypes: object(2)
# memory usage: 1.2+ KB

# %%
products_df.isna().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %%
sellers_df.isna().sum()
# Out:
# seller_id                 0
# seller_zip_code_prefix    0
# seller_city               0
# seller_state              0
# dtype: int64

# %% [markdown]
# #####Mengecek duplikasi data.

# %%
def count_duplicates(df):
  return df.duplicated().sum()

print(
    f'Total duplikasi data customers = {count_duplicates(customers_df)}\n'
    f'Total duplikasi data geolocation = {count_duplicates(geolocation_df)}\n'
    f'Total duplikasi data order items = {count_duplicates(order_items_df)}\n'
    f'Total duplikasi data order payments = {count_duplicates(order_payments_df)}\n'
    f'Total duplikasi data order reviews = {count_duplicates(order_reviews_df)}\n'
    f'Total duplikasi data order = {count_duplicates(orders_df)}\n'
    f'Total duplikasi data product category name translation = {count_duplicates(product_category_name_translation_df)}\n'
    f'Total duplikasi data products = {count_duplicates(products_df)}\n'
    f'Total duplikasi data sellers = {count_duplicates(sellers_df)}\n'
)
# Out:
# Total duplikasi data customers = 0
# Total duplikasi data geolocation = 261831
# Total duplikasi data order items = 0
# Total duplikasi data order payments = 0
# Total duplikasi data order reviews = 0
# Total duplikasi data order = 0
# Total duplikasi data product category name translation = 0
# Total duplikasi data products = 0
# Total duplikasi data sellers = 0

# %% [markdown]
# #####Melihat deskripsi data.

# %%
customers_df.describe()
# Out:
#        customer_zip_code_prefix
# count              99441.000000
# mean               35137.474583
# std                29797.938996
# min                 1003.000000
# 25%                11347.000000
# 50%                24416.000000
# 75%                58900.000000
# max                99990.000000

# %%
geolocation_df.describe()
# Out:
#        geolocation_zip_code_prefix  geolocation_lat  geolocation_lng
# count                 1.000163e+06     1.000163e+06     1.000163e+06
# mean                  3.657417e+04    -2.117615e+01    -4.639054e+01
# std                   3.054934e+04     5.715866e+00     4.269748e+00
# min                   1.001000e+03    -3.660537e+01    -1.014668e+02
# 25%                   1.107500e+04    -2.360355e+01    -4.857317e+01
# 50%                   2.653000e+04    -2.291938e+01    -4.663788e+01
# 75%                   6.350400e+04    -1.997962e+01    -4.376771e+01
# max                   9.999000e+04     4.506593e+01     1.211054e+02

# %%
order_items_df.describe()
# Out:
#        order_item_id          price  freight_value
# count  112650.000000  112650.000000  112650.000000
# mean        1.197834     120.653739      19.990320
# std         0.705124     183.633928      15.806405
# min         1.000000       0.850000       0.000000
# 25%         1.000000      39.900000      13.080000
# 50%         1.000000      74.990000      16.260000
# 75%         1.000000     134.900000      21.150000
# max        21.000000    6735.000000     409.680000

# %%
order_payments_df.describe()
# Out:
#        payment_sequential  payment_installments  payment_value
# count       103886.000000         103886.000000  103886.000000
# mean             1.092679              2.853349     154.100380
# std              0.706584              2.687051     217.494064
# min              1.000000              0.000000       0.000000
# 25%              1.000000              1.000000      56.790000
# 50%              1.000000              1.000000     100.000000
# 75%              1.000000              4.000000     171.837500
# max             29.000000             24.000000   13664.080000

# %%
order_reviews_df.describe()
# Out:
#        review_score
# count  99224.000000
# mean       4.086421
# std        1.347579
# min        1.000000
# 25%        4.000000
# 50%        5.000000
# 75%        5.000000
# max        5.000000

# %%
orders_df.describe()
# Out:
#                                 order_id                       customer_id  \
# count                              99441                             99441
# unique                             99441                             99441
# top     e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# freq                                   1                                 1
#
#        order_status order_purchase_timestamp    order_approved_at  \
# count         99441                    99441                99281
# unique            8                    98875                90733
# top       delivered      2018-04-11 10:48:14  2018-02-27 04:31:10
# freq          96478                        3                    9
#
#        order_delivered_carrier_date order_delivered_customer_date  \
# count                         97658                         96476
# unique                        81018                         95664
# ...

# %%
product_category_name_translation_df.describe()
# Out:
#        product_category_name product_category_name_english
# count                     71                            71
# unique                    71                            71
# top             beleza_saude                 health_beauty
# freq                       1                             1

# %%
products_df.describe()
# Out:
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# count         32341.000000                32341.000000        32341.000000
# mean             48.476949                  771.495285            2.188986
# std              10.245741                  635.115225            1.736766
# min               5.000000                    4.000000            1.000000
# 25%              42.000000                  339.000000            1.000000
# 50%              51.000000                  595.000000            1.000000
# 75%              57.000000                  972.000000            3.000000
# max              76.000000                 3992.000000           20.000000
#
#        product_weight_g  product_length_cm  product_height_cm  \
# count      32949.000000       32949.000000       32949.000000
# mean        2276.472488          30.815078          16.937661
# std         4282.038731          16.914458          13.637554
# ...

# %%
sellers_df.describe()
# Out:
#        seller_zip_code_prefix
# count             3095.000000
# mean             32291.059451
# std              32713.453830
# min               1001.000000
# 25%               7093.500000
# 50%              14940.000000
# 75%              64552.500000
# max              99730.000000

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# #####Mengkonversi objek/string ke tipe data datetime

# %%
orders_col = ['order_purchase_timestamp', 'order_approved_at', 'order_delivered_carrier_date', 'order_delivered_customer_date', 'order_estimated_delivery_date']
for col in orders_col:
  orders_df[col] = pd.to_datetime(orders_df[col])

# %%
order_items_col = ['shipping_limit_date']
for col in order_items_col:
  order_items_df[col] = pd.to_datetime(order_items_df[col])

# %%
order_reviews_col = ['review_creation_date','review_answer_timestamp']
for col in order_reviews_col:
  order_reviews_df[col] = pd.to_datetime(order_reviews_df[col])

# %% [markdown]
# #####Menghapus duplikasi data

# %%
geolocation_df.duplicated().sum()
# Out:
# 261831

# %%
geolocation_df.drop_duplicates(inplace=True)

# %%
geolocation_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #####Melakukan handling missing values

# %%
order_reviews_df.isna().sum()
# Out:
# review_id                      0
# order_id                       0
# review_score                   0
# review_comment_title       87656
# review_comment_message     58247
# review_creation_date           0
# review_answer_timestamp        0
# dtype: int64

# %%
order_reviews_df['review_comment_title'].fillna('No Title', inplace=True)
order_reviews_df['review_comment_message'].fillna('No Message', inplace=True)

# %%
order_reviews_df.isna().sum()
# Out:
# review_id                  0
# order_id                   0
# review_score               0
# review_comment_title       0
# review_comment_message     0
# review_creation_date       0
# review_answer_timestamp    0
# dtype: int64

# %% [markdown]
# #####Tersisa beberapa data yang masih memiliki nilai yang hilang atau null tetapi tidak dilakukan handling missing value untuk menjaga keterangan data yang akan digunakan kembali.

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %%
customers_df
# Out:
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                 ...                               ...
# 99436  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99437  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 99438  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 99439  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 99440  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
#        customer_zip_code_prefix          customer_city customer_state
# ...

# %%
customers_df.describe(include='all')
# Out:
#                              customer_id                customer_unique_id  \
# count                              99441                             99441
# unique                             99441                             96096
# top     06b8999e2fba1a1fbc88172c00ba8bc7  8d50f5eadf50201ccdcedfb9e2ac8455
# freq                                   1                                17
# mean                                 NaN                               NaN
# std                                  NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
#         customer_zip_code_prefix customer_city customer_state
# ...

# %% [markdown]
# #####Melihat asal kota mana saja dari customer yang terbanyak.

# %%
customers_df.groupby(by='customer_city')['customer_id'].nunique().sort_values(ascending=False)
# Out:
# customer_city
# sao paulo         15540
# rio de janeiro     6882
# belo horizonte     2773
# brasilia           2131
# curitiba           1521
#                   ...
# ibiara                1
# rio espera            1
# rio dos indios        1
# rio dos cedros        1
# lagoao                1
# Name: customer_id, Length: 4119, dtype: int64

# %%
geolocation_df
# Out:
#          geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                               1037       -23.545621       -46.639292
# 1                               1046       -23.546081       -46.644820
# 2                               1046       -23.546129       -46.642951
# 3                               1041       -23.544392       -46.639499
# 4                               1035       -23.541578       -46.641607
# ...                              ...              ...              ...
# 1000155                        99965       -28.180655       -52.034367
# 1000156                        99950       -28.072188       -52.011272
# 1000157                        99950       -28.068864       -52.012964
# 1000158                        99950       -28.068639       -52.010705
# 1000161                        99980       -28.388932       -51.846871
#
#         geolocation_city geolocation_state
# 0              sao paulo                SP
# ...

# %% [markdown]
# #####Mengubah teks yang memiliki format jelek menjadi teks yang sesuai.

# %%
(geolocation_df['geolocation_city'] == 'são paulo').sum()
# Out:
# 19718

# %%
geolocation_df['geolocation_city'] = geolocation_df['geolocation_city'].apply(lambda x: unidecode(x))

# %%
(geolocation_df['geolocation_city'] == 'são paulo').sum()
# Out:
# 0

# %%
geolocation_df.groupby(by=['geolocation_city','geolocation_state'])['geolocation_zip_code_prefix'].size().sort_values(ascending=False).reset_index()
# Out:
#                           geolocation_city geolocation_state  \
# 0                                sao paulo                SP
# 1                           rio de janeiro                RJ
# 2                           belo horizonte                MG
# 3                                 curitiba                PR
# 4                                 brasilia                DF
# ...                                    ...               ...
# 6345                                jordao                CE
# 6346                                silves                AM
# 6347  california da barra (barra do pirai)                RJ
# 6348                             calheiros                RJ
# 6349                          'teresopolis                RJ
#
#       geolocation_zip_code_prefix
# 0                           99643
# 1                           35175
# 2                           19474
# 3                           11263
# 4                            8791
# ...

# %% [markdown]
# #####Diketahui dari tabel dataframe diatas bahwa Sao Paulo adalah kota dengan letak demografis terbanyak.

# %%
order_payments_df.groupby(by='payment_type')['order_id'].size().sort_values(ascending=False)
# Out:
# payment_type
# credit_card    76795
# boleto         19784
# voucher         5775
# debit_card      1529
# not_defined        3
# Name: order_id, dtype: int64

# %% [markdown]
# #####Dari informasi diatas dapat diketahui bahwa jenis pembayanan yang paling banyak digunakan adalah dengan kartu kredit.

# %% [markdown]
# ####Menggabungkan `customers_df` dan `orders_df` untuk melihat keterhubungan apa saja yang ada pada kedua dataframe.

# %%
customers_orders_df = pd.merge(
    left = customers_df,
    right = orders_df,
    how = "left",
    left_on = "customer_id",
    right_on = "customer_id"
)
customers_orders_df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state  \
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP
#
#                            order_id order_status order_purchase_timestamp  \
# ...

# %% [markdown]
# ####Melakukan hal yang sama pada `products_df` dan `product_category_name_translation`.

# %%
new_products_df = pd.merge(
    left = products_df,
    right = product_category_name_translation_df,
    how = 'left',
    left_on = 'product_category_name',
    right_on = 'product_category_name'
)

col = new_products_df.pop('product_category_name_english')
new_products_df.insert(2, col.name, col)
new_products_df.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#   product_category_name_english  product_name_lenght  \
# 0                     perfumery                 40.0
# 1                           art                 44.0
# 2                sports_leisure                 46.0
# 3                          baby                 27.0
# 4                    housewares                 37.0
#
#    product_description_lenght  product_photos_qty  product_weight_g  \
# 0                       287.0                 1.0             225.0
# 1                       276.0                 1.0            1000.0
# 2                       250.0                 1.0             154.0
# ...

# %% [markdown]
# ####Melakukan penggabungan seluruh dataset menjadi satu dataset utuh untuk divisualisasikan.

# %%
merge1 = pd.merge(
    left = customers_orders_df,
    right = order_payments_df,
    how = 'left',
    left_on = 'order_id',
    right_on = 'order_id'
)
merge1.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state  \
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP
#
#                            order_id order_status order_purchase_timestamp  \
# ...

# %%
merge2 = pd.merge(
    left = merge1,
    right = order_items_df,
    how = 'left',
    left_on = 'order_id',
    right_on = 'order_id'
)
merge2.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state  \
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP
#
#                            order_id order_status order_purchase_timestamp  \
# ...

# %%
merge3 = pd.merge(
    left =merge2,
    right = new_products_df,
    how = 'left',
    left_on = 'product_id',
    right_on = 'product_id'
)
merge3.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state  \
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP
#
#                            order_id order_status order_purchase_timestamp  \
# ...

# %%
merge4 = pd.merge(
    left = merge3,
    right = sellers_df,
    how = 'left',
    left_on = 'seller_id',
    right_on = 'seller_id'
)
merge4.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state  \
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP
#
#                            order_id order_status order_purchase_timestamp  \
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
df_all = pd.merge(
    left = merge4,
    right = order_reviews_df,
    how = 'left',
    left_on = 'order_id',
    right_on = 'order_id'
)
df_all.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state  \
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP
#
#                            order_id order_status order_purchase_timestamp  \
# ...

# %%
df_all.describe()
# Out:
#        customer_zip_code_prefix  payment_sequential  payment_installments  \
# count             119143.000000       119140.000000         119140.000000
# mean               35033.451298            1.094737              2.941246
# std                29823.198969            0.730141              2.777848
# min                 1003.000000            1.000000              0.000000
# 25%                11250.000000            1.000000              1.000000
# 50%                24240.000000            1.000000              2.000000
# 75%                58475.000000            1.000000              4.000000
# max                99990.000000           29.000000             24.000000
#
#        payment_value  order_item_id          price  freight_value  \
# count  119140.000000  118310.000000  118310.000000  118310.000000
# mean      172.735135       1.196543     120.646603      20.032387
# std       267.776077       0.699489     184.109691      15.836850
# ...

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1: Produk apa yang memiliki jumlah pembelian terbanyak?

# %%
df_all.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state  \
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP
#
#                            order_id order_status order_purchase_timestamp  \
# ...

# %%
counts_product = df_all.groupby('product_category_name_english')['product_id'].count().reset_index()
df_sort = counts_product.sort_values(by='product_id', ascending=False)

df_sort
# Out:
#    product_category_name_english  product_id
# 7                 bed_bath_table       11988
# 43                 health_beauty       10032
# 65                sports_leisure        9004
# 39               furniture_decor        8832
# 15         computers_accessories        8150
# ..                           ...         ...
# 3          arts_and_craftmanship          24
# 52                    la_cuisine          16
# 11             cds_dvds_musicals          14
# 29     fashion_childrens_clothes           8
# 61         security_and_services           2
#
# [71 rows x 2 columns]

# %%
fig, ax = plt.subplots(1, 2, figsize=(24, 6))

colors = ["#FF5733", "#FFD700", "#C0C0C0", "#808080", "#000000"]

sns.barplot(x="product_id", y="product_category_name_english", data=df_sort.head(5), palette=colors, ax=ax[0])
ax[0].set_ylabel(None)
ax[0].set_xlabel(None)
ax[0].set_title("Top Selling Products", loc="center", fontsize=18)
ax[0].tick_params(axis='y', labelsize=15)

sns.barplot(x="product_id", y="product_category_name_english", data=df_sort.sort_values(by="product_id", ascending=True).head(5), palette=colors, ax=ax[1])
ax[1].set_ylabel(None)
ax[1].set_xlabel(None)
ax[1].invert_xaxis()
ax[1].yaxis.set_label_position("right")
ax[1].yaxis.tick_right()
ax[1].set_title("Least Selling Products", loc="center", fontsize=18)
ax[1].tick_params(axis='y', labelsize=15)

plt.suptitle("Top and Least Sold Products", fontsize=20)
plt.show()
# Out:
# <ipython-input-83-5885ee899a88>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="product_id", y="product_category_name_english", data=df_sort.head(5), palette=colors, ax=ax[0])
# <ipython-input-83-5885ee899a88>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="product_id", y="product_category_name_english", data=df_sort.sort_values(by="product_id", ascending=True).head(5), palette=colors, ax=ax[1])

# %% [markdown]
# ### Pertanyaan 2: Seberapa puas pelanggan terhadap layanan yang diberikan (review)?

# %%
reviews = df_all['review_score'].value_counts().sort_values(ascending=False)

# %%
reviews.index

# %%
reviews.values

# %%
rating_counts = df_all['review_score'].value_counts().sort_values(ascending=False)

max_rating = rating_counts.idxmax()

sns.set(style="whitegrid")

plt.figure(figsize=(10, 5))
sns.barplot(x=rating_counts.index,
            y=rating_counts.values,
            order=rating_counts.index,
            palette=["#FF5733" if rating == max_rating else "#D3D3D3" for rating in rating_counts.index]
            )

plt.title("Customer Ratings for Service", fontsize=15)
plt.xlabel("Rating")
plt.ylabel("Number of Customers")
plt.xticks(fontsize=12)
plt.show()
# Out:
# <ipython-input-84-86c026366493>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=rating_counts.index,

# %% [markdown]
# ###Pertanyaan 3: Bagaimana data pembelian bulanan?

# %%
monthly_spend_df = df_all.resample(rule='M', on='order_approved_at').agg({
            "price": "sum"
})
monthly_spend_df = monthly_spend_df.reset_index()
monthly_spend_df.rename(columns={
            "price": "Total Spending"
        }, inplace=True)

monthly_spend_df
# Out:
#    order_approved_at  Total Spending
# 0         2016-09-30          134.97
# 1         2016-10-31        51201.31
# 2         2016-11-30            0.00
# 3         2016-12-31           10.90
# 4         2017-01-31       124313.26
# 5         2017-02-28       262281.82
# 6         2017-03-31       394384.70
# 7         2017-04-30       390306.86
# 8         2017-05-31       550323.59
# 9         2017-06-30       461045.05
# 10        2017-07-31       531342.05
# 11        2017-08-31       605325.32
# 12        2017-09-30       654698.76
# 13        2017-10-31       704026.32
# 14        2017-11-30      1039022.61
# 15        2017-12-31       795824.02
# 16        2018-01-31       986284.61
# 17        2018-02-28       882417.57
# 18        2018-03-31      1039716.71
# 19        2018-04-30      1010481.51
# 20        2018-05-31      1056093.87
# 21        2018-06-30       914410.56
# 22        2018-07-31       908431.56
# 23        2018-08-31       909806.29
# ...

# %%
monthly_spend_df['order_approved_at'] = monthly_spend_df['order_approved_at'].dt.strftime('%B')
monthly_spend_df
# Out:
#    order_approved_at  Total Spending
# 0          September          134.97
# 1            October        51201.31
# 2           November            0.00
# 3           December           10.90
# 4            January       124313.26
# 5           February       262281.82
# 6              March       394384.70
# 7              April       390306.86
# 8                May       550323.59
# 9               June       461045.05
# 10              July       531342.05
# 11            August       605325.32
# 12         September       654698.76
# 13           October       704026.32
# 14          November      1039022.61
# 15          December       795824.02
# 16           January       986284.61
# 17          February       882417.57
# 18             March      1039716.71
# 19             April      1010481.51
# 20               May      1056093.87
# 21              June       914410.56
# 22              July       908431.56
# 23            August       909806.29
# ...

# %%
monthly_spend_df = monthly_spend_df.sort_values('Total Spending').drop_duplicates('order_approved_at', keep ='last')
monthly_spend_df
# Out:
#    order_approved_at  Total Spending
# 12         September       654698.76
# 13           October       704026.32
# 15          December       795824.02
# 17          February       882417.57
# 22              July       908431.56
# 23            August       909806.29
# 21              June       914410.56
# 16           January       986284.61
# 19             April      1010481.51
# 14          November      1039022.61
# 18             March      1039716.71
# 20               May      1056093.87

# %%
custom_months_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
monthly_spend_df['month_category'] = pd.Categorical(monthly_spend_df['order_approved_at'], categories=custom_months_order, ordered=True)
sorted_monthly_spend_df = monthly_spend_df.sort_values(by='month_category')
sorted_monthly_spend_df = sorted_monthly_spend_df.drop(columns=['month_category'])

print(sorted_monthly_spend_df)
# Out:
#    order_approved_at  Total Spending
# 16           January       986284.61
# 17          February       882417.57
# 18             March      1039716.71
# 19             April      1010481.51
# 20               May      1056093.87
# 21              June       914410.56
# 22              July       908431.56
# 23            August       909806.29
# 12         September       654698.76
# 13           October       704026.32
# 14          November      1039022.61
# 15          December       795824.02

# %%
print('Total Spending: ', monthly_spend_df['Total Spending'].sum())
print('Average of Spending: ', monthly_spend_df['Total Spending'].mean())
# Out:
# Total Spending:  10901214.39
# Average of Spending:  908434.5325000001

# %%
monthly_orders_df = df_all.resample(rule='M', on='order_approved_at').agg({
    "order_id": "count",
})
monthly_orders_df
# Out:
#                    order_id
# order_approved_at
# 2016-09-30                3
# 2016-10-31              398
# 2016-11-30                0
# 2016-12-31                1
# 2017-01-31              984
# 2017-02-28             2104
# 2017-03-31             3263
# 2017-04-30             2845
# 2017-05-31             4471
# 2017-06-30             3863
# 2017-07-31             4887
# 2017-08-31             5286
# 2017-09-30             5211
# 2017-10-31             5630
# 2017-11-30             9017
# 2017-12-31             6846
# 2018-01-31             8541
# 2018-02-28             8041
# 2018-03-31             8705
# 2018-04-30             8075
# 2018-05-31             8497
# 2018-06-30             7391
# 2018-07-31             7234
# 2018-08-31             7672
# 2018-09-30                1

# %%
monthly_orders_df.index
# Out:
# DatetimeIndex(['2016-09-30', '2016-10-31', '2016-11-30', '2016-12-31',
#                '2017-01-31', '2017-02-28', '2017-03-31', '2017-04-30',
#                '2017-05-31', '2017-06-30', '2017-07-31', '2017-08-31',
#                '2017-09-30', '2017-10-31', '2017-11-30', '2017-12-31',
#                '2018-01-31', '2018-02-28', '2018-03-31', '2018-04-30',
#                '2018-05-31', '2018-06-30', '2018-07-31', '2018-08-31',
#                '2018-09-30'],
#               dtype='datetime64[ns]', name='order_approved_at', freq=None)

# %%
monthly_orders_df.index = monthly_orders_df.index.strftime('%B') # Mengubah format tanggal indeks menjadi Bulan
monthly_orders_df = monthly_orders_df.reset_index()
monthly_orders_df.rename(columns={
    "order_id": "order_count",
}, inplace=True)
monthly_orders_df
# Out:
#    order_approved_at  order_count
# 0          September            3
# 1            October          398
# 2           November            0
# 3           December            1
# 4            January          984
# 5           February         2104
# 6              March         3263
# 7              April         2845
# 8                May         4471
# 9               June         3863
# 10              July         4887
# 11            August         5286
# 12         September         5211
# 13           October         5630
# 14          November         9017
# 15          December         6846
# 16           January         8541
# 17          February         8041
# 18             March         8705
# 19             April         8075
# 20               May         8497
# 21              June         7391
# 22              July         7234
# 23            August         7672
# 24         September            1

# %%
sorted_monthly_orders_df = monthly_orders_df.sort_values('order_count').drop_duplicates('order_approved_at', keep='last')
sorted_monthly_orders_df
# Out:
#    order_approved_at  order_count
# 12         September         5211
# 13           October         5630
# 15          December         6846
# 22              July         7234
# 21              June         7391
# 23            August         7672
# 17          February         8041
# 19             April         8075
# 20               May         8497
# 16           January         8541
# 18             March         8705
# 14          November         9017

# %%
month_mapping = {
    "January": 1,
    "February": 2,
    "March": 3,
    "April": 4,
    "May": 5,
    "June": 6,
    "July": 7,
    "August": 8,
    "September": 9,
    "October": 10,
    "November": 11,
    "December": 12
}

monthly_orders_df["month_numeric"] = monthly_orders_df["order_approved_at"].map(month_mapping)
monthly_orders_df = monthly_orders_df.sort_values("month_numeric")
monthly_orders_df = monthly_orders_df.drop("month_numeric", axis=1)
monthly_orders_df
# Out:
#    order_approved_at  order_count
# 16           January         8541
# 4            January          984
# 17          February         8041
# 5           February         2104
# 18             March         8705
# 6              March         3263
# 19             April         8075
# 7              April         2845
# 8                May         4471
# 20               May         8497
# 9               June         3863
# 21              June         7391
# 22              July         7234
# 10              July         4887
# 11            August         5286
# 23            August         7672
# 0          September            3
# 12         September         5211
# 24         September            1
# 13           October         5630
# 1            October          398
# 14          November         9017
# 2           November            0
# 3           December            1
# 15          December         6846

# %%
max_order_count_date = monthly_orders_df[monthly_orders_df['order_count'] == monthly_orders_df['order_count'].max()]['order_approved_at'].values[0]
max_order_count_date
# Out:
# 'November'

# %%
plt.figure(figsize=(10, 5))
plt.plot(
    monthly_orders_df["order_approved_at"],
    monthly_orders_df["order_count"],
    linestyle='-',
    marker='o',
    markersize=8,
    color="#72BCD4",
    linewidth=2
)
plt.title("Monthly Orders Distribution in 2018", loc="center", fontsize=20)
plt.xlabel("Month", fontsize=12)
plt.ylabel("Number of Orders", fontsize=12)
plt.xticks(fontsize=10, rotation=25)
plt.yticks(fontsize=10)
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(
    monthly_spend_df["order_approved_at"],
    monthly_spend_df["Total Spending"],
    linestyle='-',
    marker='o',
    markersize=8,
    color="#72BCD4",
    linewidth=2
)
plt.title("Total Customer Expenditure in 2018", loc="center", fontsize=20)
plt.xlabel("Date", fontsize=12)
plt.ylabel("Total Spending", fontsize=12)
plt.xticks(fontsize=10, rotation=25)
plt.yticks(fontsize=10)
plt.grid(True)
plt.show()

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - **Conclution pertanyaan 1**
# Berdasarkan data yang divisualisasikan, produk `beth_bad_table` menerima pembelian konsumen terbanyak, sedangkan produk `security_and_service` menerima pembelian konsumen paling sedikit.

# %% [markdown]
# - **Conclution pertanyaan 2**
# Tingkat kepuasan pelanggan sebagian besar memuaskan, seperti yang ditunjukkan oleh data yang divisualisasikan. Nilai penilaian untuk sebagian besar pelanggan mencapai nilai sempurna, yaitu nilai 5, dan nilai rata-ratanya adalah 4 jika dibulatkan.

# %% [markdown]
# - **Conclution pertanyaan 3**
# Data pembelian pelanggan bernilai fluaktif, yang berarti bahwa nilai pembelian pelanggan meningkat dan kadang-kadang menurun setiap bulan. Berdasarkan data terkait, puncak pembelian maksimum pelanggan terjadi pada bulan November dan puncak pembelian minimum pelanggan terjadi pada bulan September.
